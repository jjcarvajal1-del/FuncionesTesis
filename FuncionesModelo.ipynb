# %%
# ============================================
# IMPORTACIÓN DE LIBRERÍAS Y FUNCIONES
# ============================================

import openseespy.opensees as ops
import opsvis as opsv
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import csv as csv
from FuncionesV2 import pushover

# %%
pushover(420,200,21,20000,28,25000,0.3,0.4,0.4,0.5,40,5.0,0.2,1.8)
# Out:
# Configuración definida exitosamente
# Materiales definidos exitosamente
# SectionForceDeformation *getSectionForceDeformation(int tag) - none found with tag: 2
# section 2not found
# ---------------------------------------------------------------------------
# OpenSeesError                             Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 pushover(420,200,21,20000,28,25000,0.3,0.4,0.4,0.5,40,5.0,0.2,1.8)
#
# File c:\Users\jjcar\OneDrive\2. INFORMACIÓN TÉCNICA\12. POSTGRADO ESTRUCTURAS\TESIS2\INGENIERÍA\Modelo OpenseesPy Funciones\FuncionesV2.py:236, in pushover(Vfy, VEs, Vfc_vigas, VEc_vigas, Vfc_columnas, VEc_columnas, Vb1, Vh1, Vb2, Vh2, Vrec, VWentrepiso, VWcubierta, VWviva)
#     234 ops.beamIntegration('Lobatto', 1, 2, nIpcol)                   # Integración de Lobatto para columnas
#     235 for i in range(1,46):
# --> 236     ops.element('dispBeamColumn',i,*[i,i+15],1,1,'-cMass',0)   # Creación de columnas entre pisos 1-2 y 2-3
#     237 # DEFINICIÓN DE VIGAS
#     238 nIpvig=3                                      # Número de puntos de integración para vigas
#
# OpenSeesError: See stderr output
